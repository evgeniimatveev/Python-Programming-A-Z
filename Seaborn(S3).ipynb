# %% [markdown]
# # PYTHON PROGRAMMING FUNDAMENTALS - PART B

# %% [markdown]
# - Seaborn is a visualization library that sits on top of matplotlib
# - Seaborn offers enhanced features compared to matplotlib
# - https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# # EXAMPLE #1

# %%
# 📚 Import essential libraries  
import pandas as pd  # For handling tabular data 🐼  
import numpy as np  # For numerical operations 🔢  
import matplotlib.pyplot as plt  # For visualization 🎨  
import seaborn as sns  # For statistical data visualization 📊  

# 🔬 Import the dataset from scikit-learn  
from sklearn.datasets import load_breast_cancer

# %%
# 🔬 Load the Breast Cancer dataset  
cancer = load_breast_cancer()  

# 🏗️ Convert the dataset into a Pandas DataFrame  
df_cancer = pd.DataFrame(
    np.c_[cancer['data'], cancer['target']],  # Combine feature data with target  
    columns=np.append(cancer['feature_names'], ['target'])  # Assign column names  
)  

# 🏆 Display the first few rows for an overview  
df_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# 🎭 Seaborn Pairplot – Visualizing Feature Relationships  
sns.pairplot(df_cancer,  
             hue="target",  # 🎨 Color by class (Malignant = Orange, Benign = Blue)  
             vars=['mean radius', 'mean texture', 'mean area', 'mean perimeter', 'mean smoothness'],  
             palette="coolwarm",  # 🌈 Beautiful color mapping  
             markers=["o", "s"],  # 🔵 Use 'o' for benign, 🟠 's' for malignant  
             diag_kind="hist")  # 📊 Histograms on diagonal for better readability  

# 🏆 Display the plot  
plt.show()

# %%
# 📊 Corrected Countplot: Assign x explicitly and disable legend  
sns.countplot(x=df_cancer['target'], hue=df_cancer['target'], palette="coolwarm", legend=False)  

# 🎯 Display the plot  
plt.show()

# %%
# 🎭 Enhanced Scatterplot: Adding size, style & legend  
plt.figure(figsize=(8,6))  # 🔍 Adjust figure size for better clarity  
sns.scatterplot(x='mean area', y='mean smoothness', hue='target', data=df_cancer, palette="coolwarm",  
                style="target", size="mean perimeter", sizes=(10, 100))  # 🎯 Different styles & sizes  
plt.title("Mean Area vs Mean Smoothness with Size Representation")  # 🏆 Add a title  
plt.xlabel("Mean Area (Size of Tumor)")  # 🏷 Label X-axis  
plt.ylabel("Mean Smoothness")  # 🏷 Label Y-axis  
plt.legend(title="Cancer Type", labels=["Malignant (0)", "Benign (1)"])  # 🎨 Improved legend  
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 📏 **Set figure size for better readability**
plt.figure(figsize=(17, 10)) 

# 🎨 **Create an enhanced heatmap with better visualization**
sns.heatmap(
    df_cancer.corr(),  # 📊 Compute correlation matrix
    annot=True,  # 📝 Display correlation values inside cells
    fmt=".2f",  # 🔢 Format numbers to 2 decimal places
    cmap="coolwarm",  # 🎨 Use color theme for better contrast
    linewidths=1,  # ➖ Add grid lines between cells
    square=False,  # 🔲 Ensure rectangular aspect ratio
    cbar_kws={"shrink": 0.8, "label": "Correlation Strength"}  # 🎛 Customize color bar
)

# 🏷 **Add title and labels for clarity**
plt.title(" Titanic Feature Correlation Heatmap", fontsize=16, fontweight='bold')  # ✅ Увеличили размер заголовка
plt.xticks(rotation=45, ha='right', fontsize=10)  # 🔄 Улучшили читаемость подписей
plt.yticks(fontsize=10)  # 📏 Сделали подписи на оси Y четче

# 🖼 **Display the heatmap**
plt.show()

# %% [markdown]
# # EXAMPLE #2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# 🎯 Load Titanic dataset
titanic_data = sns.load_dataset("titanic")

# 🏷️ Display first 5 rows to understand the data
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 🚢 Count of passengers in each class
plt.figure(figsize=(8, 5))  # 📏 Adjust figure size
sns.countplot(x="class", hue="class", data=titanic_data, palette="viridis", legend=False)  # 🎨 Use color palette

plt.xlabel("Passenger Class", fontsize=12)  # 🏷️ Label x-axis
plt.ylabel("Count", fontsize=12)  # 🏷️ Label y-axis
plt.title("Titanic Passenger Class Distribution", fontsize=14)  # 📊 Standard title without emoji
plt.show()  # 🎉 Display the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 🎯 Survival distribution across passenger classes
plt.figure(figsize=(8, 5))  # 📏 Adjust figure size

# 🛟 Using 'hue' to fix the warning and improve clarity
sns.countplot(x="survived", hue="survived", data=titanic_data, palette="coolwarm", legend=False)

# 🏷️ Label axes for clarity
plt.xlabel("Survival (0 = No, 1 = Yes)", fontsize=12)  # Label x-axis
plt.ylabel("Count", fontsize=12)  # Label y-axis
plt.title("Titanic Survival Count", fontsize=14)  # 🏛️ Add title without emoji to avoid font issues

# 🎨 Improve visual aesthetics
plt.xticks([0, 1], ["Did Not Survive", "Survived"])  # Custom x-axis labels
plt.grid(axis="y", linestyle="--", alpha=0.7)  # Light grid for readability

plt.show()  # 🎉 Display the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 📥 Load Titanic dataset
titanic_data = sns.load_dataset("titanic")

# 🎨 Set Seaborn style for better visualization
sns.set_style("whitegrid")

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 📦 **Boxplot**: Shows median, quartiles, and outliers
plt.figure(figsize=(8, 5))  # 🔹 Adjust figure size
sns.boxplot(x='class', y='age', data=titanic_data, hue='class', palette="Set2")  # ✅ FIXED: Added `hue`

# 🏷️ Labels and title
plt.xlabel("Passenger Class", fontsize=12)
plt.ylabel("Age", fontsize=12)
plt.title(" Titanic Age Distribution (Boxplot)", fontsize=14)

plt.show()  # 🔹 Display the plot

# %%
# 🐝 **Swarmplot**: Individual data points (less overlap)
plt.figure(figsize=(8, 5))  # 🔹 Adjust figure size
sns.swarmplot(x='class', y='age', data=titanic_data, hue='class', palette="Set1", size=2.5, alpha=0.7, dodge=False)  
# ✅ FIXED: `size=2.5` reduces marker size, `dodge=False` prevents overlap issues

# 🏷️ Labels and title
plt.xlabel("Passenger Class", fontsize=12)
plt.ylabel("Age", fontsize=12)
plt.title(" Titanic Age Distribution (Swarmplot)", fontsize=14)

plt.show()  # 🔹 Display the plot

# %%
import seaborn as sns  # 📊 Import seaborn for data visualization
import matplotlib.pyplot as plt  # 📈 Import matplotlib for plotting
import pandas as pd  # 🗂 Import pandas for data manipulation

# 📌 Load Titanic dataset
titanic_data = sns.load_dataset("titanic")

# 🛑 Drop non-numeric columns for correlation matrix to work properly
numeric_data = titanic_data.select_dtypes(include=['number'])

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 📦 Boxplot: Shows distribution of age across passenger classes
sns.boxplot(x="class", y="age", data=titanic_data)
plt.xlabel("Passenger Class")  # 🔠 Label x-axis
plt.ylabel("Age")  # 🔠 Label y-axis
plt.title(" Titanic Age Distribution (Boxplot)")  # 🏷️ Add title
plt.show()  # 👀 Display the plot

# %%
# 📊 Jointplot: Shows relation between fare and age with marginal histograms
sns.jointplot(x="fare", y="age", data=titanic_data)
plt.show()  # 👀 Display the plot

# %%
# 🔥 Heatmap: Displays correlation between numerical variables
plt.figure(figsize=(10, 8))  # 📏 Set figure size for better readability
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")  # 🎨 Add color mapping
plt.title(" Titanic Feature Correlation Heatmap")  # 🏷️ Add title
plt.show()  # 👀 Display the plot

# %% [markdown]
# # PERFECT JOB, NOW YOU ARE READY FOR THE PRACTICAL PART OF THE COURSE!
