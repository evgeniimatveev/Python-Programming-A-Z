# %% [markdown]
# # S1 – Quick Start: Variables & Loops
#
# Добро пожаловать в мини-разминку по разделу **S1 – Python Basics**.
#
# В этом ноутбуке ты:
# - создашь пару переменных,
# - поработаешь со списком,
# - напишешь простую функцию и цикл `for`.

# %%
# 1) Базовые переменные

course = "Python Programming A-Z"
section = "S1 - Python Basics"
lessons = ["Variables", "Strings", "Lists", "Tuples", "Dictionaries"]

print(course)
print(section)
print("Lessons in this section:")

for i, name in enumerate(lessons, start=1):
    print(f"{i}. {name}")

# %%
# 2) Простая функция + проверка

def describe_lesson(title: str, difficulty: str = "beginner") -> str:
    """Вернуть описание урока с уровнем сложности."""
    return f"Lesson: {title} | Difficulty: {difficulty}"


examples = [
    ("Variables", "beginner"),
    ("If/Else", "beginner"),
    ("Loops", "beginner"),
]

for title, level in examples:
    print(describe_lesson(title, level))
